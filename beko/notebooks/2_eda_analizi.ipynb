# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
import plotly.express as px
import plotly.graph_objects as go
warnings.filterwarnings('ignore')

# %%
df_beko = pd.read_csv(r"../web-scraping-data/data/claned/beko_claned.csv")
df_beko.head()
# Out:
#                                         Product_Link  \
# 0  https://www.beko.com.tr/no-frost-buzdolabi/683...
# 1  https://www.beko.com.tr/no-frost-buzdolabi/678...
# 2  https://www.beko.com.tr/no-frost-buzdolabi/678...
# 3  https://www.beko.com.tr/no-frost-buzdolabi/678...
# 4  https://www.beko.com.tr/no-frost-buzdolabi/670...
#
#                                         Product_Name    Price Energy_Class  \
# 0  683616 EI Yapay Zeka Teknolojili No Frost Buzd...  88409.0            C
# 1               678551 EGC AI Fit No Frost Buzdolabı      NaN            D
# 2  678551 EBC AI Fit Beyaz Cam Yapay Zeka Teknolo...      NaN            D
# 3            678551 ESC Siyah Cam No Frost Buzdolabı      NaN            D
# 4        670475 IEBC AI Beyaz Cam No Frost Buzdolabı      NaN            E
#
#    Favorite_Count       Product_Group Main_Category Subcategory  \
# 0           104.0  No Frost Buzdolabi    Beyaz Eşya   Buzdolabı
# 1             4.0  No Frost Buzdolabi    Beyaz Eşya   Buzdolabı
# 2             7.0  No Frost Buzdolabi    Beyaz Eşya   Buzdolabı
# 3            41.0  No Frost Buzdolabi    Beyaz Eşya   Buzdolabı
# 4             4.0  No Frost Buzdolabi    Beyaz Eşya   Buzdolabı
#
#   Freezer_Compartment_Technology  Depth  ...  Charging_Time_min  Power_(W)  \
# 0              Sabit Set Değerli   76.2  ...                NaN        NaN
# 1                            NaN   76.0  ...                NaN        NaN
# 2                            NaN   76.0  ...                NaN        NaN
# 3              Sabit Set Değerli   76.0  ...                NaN        NaN
# 4                            NaN   74.5  ...                NaN        NaN
#
#    Water_Capacity_(L) RAM_(GB) Storage_(GB) Battery_(mAh)  Spin_Speed  \
# 0               615.0      NaN          NaN           NaN         NaN
# 1               551.0      NaN          NaN           NaN         NaN
# 2               551.0      NaN          NaN           NaN         NaN
# 3               551.0      NaN          NaN           NaN         NaN
# 4               475.0      NaN          NaN           NaN         NaN
#
#    Number_of_Programs Number_of_Functions  Screen_Size_Inch
# 0                   0                   0               NaN
# 1                   0                   0               NaN
# 2                   0                   0               NaN
# 3                   0                   0               NaN
# 4                   0                   0               NaN
#
# [5 rows x 370 columns]
